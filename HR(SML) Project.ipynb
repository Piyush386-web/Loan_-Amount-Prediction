# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('hrdataset.csv')

# %%
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %% [markdown]
# # Doing Deep Copy to keep a copy of raw data for future references if needed.
# df1 = df.copy()
# df1

# %%
df.head(10)
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
# 5    Male         0           No   Yes        Two year     Yes     No   23
# 6    Male         0          Yes    No        Two year     Yes     No   23
# 7  Female         0           No   Yes        One year     Yes     No   24
# 8  Female         1           No   Yes  Month-to-month     Yes    Yes   24
# 9    Male         0           No   Yes  Month-to-month     Yes     No   43
#
#        Salary     Base_pay       Bonus  Unit_Price    Volume  openingbalance  \
# ...

# %%
df.tail(10)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4990    Male         0           No   Yes  Month-to-month      No     No   70
# 4991    Male         1           No   Yes        Two year      No     No   70
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales          8
# Months               0
# Education            0
# dtype: int64

# %%
df.size
# Out:
# 100000

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %% [markdown]
# # Replace empty strings or whitespace strings with NaN

# %%
df = df.replace(r'^\s*$', float(np.NaN),regex=True)

# %%
df.tail(10)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4990    Male         0           No   Yes  Month-to-month      No     No   70
# 4991    Male         1           No   Yes        Two year      No     No   70
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
df['Total_Sales'] =df['Total_Sales'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales         16
# Months               0
# Education            0
# dtype: int64

# %%
total =df.isnull().sum().sort_values(ascending=False)
percent_1 = (df.isnull().sum()/df.shape[0])*100
percent_2 = round(percent_1,1).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis =1, keys =['Total','%'])
missing_data.head(3)
# Out:
#                 Total     %
# openingbalance   1476  29.5
# Base_pay           23   0.5
# Total_Sales        16   0.3

# %%
from sklearn.impute import KNNImputer
x =df[['Base_pay','openingbalance','Total_Sales']]
imputer =KNNImputer(n_neighbors=2)
x =imputer.fit_transform(x)

# %%
df[['Base_pay','openingbalance','Total_Sales']]=pd.DataFrame(x,columns=['Base_pay','openingbalance','Total_Sales'])

# %%
df.isna().sum()
# Out:
# Gender            0
# Business          0
# Dependancies      0
# Calls             0
# Type              0
# Billing           0
# Rating            0
# Age               0
# Salary            0
# Base_pay          0
# Bonus             0
# Unit_Price        0
# Volume            0
# openingbalance    0
# closingbalance    0
# low               0
# Unit_Sales        0
# Total_Sales       0
# Months            0
# Education         0
# dtype: int64

# %% [markdown]
# # EDA

# %%
degree_wise=df.Education.value_counts()
degree_wise

# %%
Gender_wise=df.Gender.value_counts()
Gender_wise
# Out:
# Gender
# Male      2528
# Female    2472
# Name: count, dtype: int64

# %%
Rating_wise=df.Rating.value_counts()
Rating_wise
# Out:
# Rating
# No     3682
# Yes    1318
# Name: count, dtype: int64

# %%
call_wise=df.Calls.value_counts()
call_wise
# Out:
# Calls
# Yes    4539
# No      461
# Name: count, dtype: int64

# %%
Dependencies_wise=df.Dependancies.value_counts()
Dependencies_wise
# Out:
# Dependancies
# No     3524
# Yes    1476
# Name: count, dtype: int64

# %%
Age_wise=df.Age.value_counts()
Age_wise
# Out:
# Age
# 50    256
# 53    254
# 55    248
# 54    245
# 51    244
#      ...
# 78      2
# 80      1
# 82      1
# 85      1
# 79      1
# Name: count, Length: 65, dtype: int64

# %%
Type_wise=df.Type.value_counts()
Type_wise
# Out:
# Type
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: count, dtype: int64

# %%
Billing_wise=df.Billing.value_counts()
Billing_wise
# Out:
# Billing
# Yes    2956
# No     2044
# Name: count, dtype: int64

# %% [markdown]
# # To Check Skewness and Density

# %%
sns.set(style='darkgrid')
fig, axs=plt.subplots(2,2,figsize=(10,10))
sns.histplot(data=df, x='Salary',kde=True, color='red',ax=axs[0,0])
sns.histplot(data=df, x='Base_pay',kde=True, color='Blue',ax=axs[0,1])
sns.histplot(data=df, x='Bonus',kde=True, color='gold',ax=axs[1,0])
sns.histplot(data=df, x='Age',kde=True, color='black',ax=axs[1,1])
plt.show()

# %%
fig, axs=plt.subplots(1,2,figsize=(10,5))
sns.histplot(data=df, x='low',kde=True, color='red',ax=axs[0])
sns.histplot(data=df, x='Total_Sales',kde=True, color='Navy',ax=axs[1])
plt.show()

# %%
sns.set(style='darkgrid')
fig, axs=plt.subplots(2,2,figsize=(10,5))
sns.boxplot(data=df, x='Salary', color='red',ax=axs[0,0])
sns.boxplot(data=df, x='Base_pay', color='Blue',ax=axs[0,1])
sns.boxplot(data=df, x='Bonus', color='gold',ax=axs[1,0])
sns.boxplot(data=df, x='Age',color='black',ax=axs[1,1])
plt.show()

# %%
sns.set(style='darkgrid')
fig, axs=plt.subplots(2,2,figsize=(10,5))
sns.boxplot(data=df, x='low', color='red',ax=axs[0,0])
sns.boxplot(data=df, x='Total_Sales', color='Navy',ax=axs[0,1])
sns.boxplot(data=df, x='Volume', color='yellow',ax=axs[1,0])
sns.boxplot(data=df, x='Months',color='skyblue',ax=axs[1,1])
plt.show()

# %% [markdown]
# # Stastical Approach QQplot to see the distribution

# %% [markdown]
# # QQ plot for salary

# %%
import pingouin as pg
pg.qqplot(df['Salary'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Base_pay'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Bonus'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Total_Sales'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Unit_Price'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Age'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Volume'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['openingbalance'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['closingbalance'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['low'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Business'],dist ='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
df3 =df.drop(['Business'],axis =1)
df3.head()
# Out:
#    Gender Dependancies Calls            Type Billing Rating  Age   Salary  \
# 0  Female           No   Yes  Month-to-month      No    Yes   18  5089.00
# 1  Female           No   Yes  Month-to-month      No    Yes   19  5698.12
# 2    Male           No   Yes  Month-to-month     Yes     No   22  5896.65
# 3  Female           No   Yes  Month-to-month     Yes    Yes   21  6125.12
# 4    Male           No   Yes  Month-to-month     Yes    Yes   23  6245.00
#
#    Base_pay     Bonus  Unit_Price    Volume  openingbalance  closingbalance  \
# 0  2035.600  254.4500        3.77  21226600            3.75            3.76
# 1  2279.248  284.9060        3.74  10462800            3.85            3.68
# 2  2358.660  294.8325        3.89  18761000            4.23            4.29
# 3  2450.048  306.2560        4.35  66130600            4.26            4.31
# 4  2498.000  312.2500        4.34  26868200            4.79            4.41
#
#     low  Unit_Sales  Total_Sales  Months            Education
# ...

# %%
df3_numeric =df3.select_dtypes(include ='number')

# %%
df3_numeric.corr(method ='spearman')
plt.figure(figsize=(20,8))
heatmap= sns.heatmap(df3_numeric.corr(method ='spearman').round(3),vmin=-1,
vmax=1,annot=True)
font2={'family':'serif','color':'green','size':20}
plt.title('Spearman Rank Correlation',font2)
plt.show()

# %% [markdown]
# # The relationship between Categorical variables and the Dependent variable

# %%
df.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['Gender', 'Dependancies', 'Calls', 'Type', 'Billing', 'Rating', 'Education']

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x='Gender',y='Salary',color='orange')
plt.title('Salary vs Gender')
# Out:
# Text(0.5, 1.0, 'Salary vs Gender')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x='Education',y='Salary',color='Green')
plt.title('Salary vs Education')
# Out:
# Text(0.5, 1.0, 'Salary vs Education')

# %%
plt.figure(figsize=(12,7))
sns.boxplot(data=df,x='Type',y='Salary',palette='winter')
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_8344\1288638881.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Type',y='Salary',palette='winter')
# <Axes: xlabel='Type', ylabel='Salary'>

# %%
plt.figure(figsize=(9,7))
sns.boxplot(data=df,x='Rating',y='Salary')
plt.title('Salary vs Rating')
# Out:
# Text(0.5, 1.0, 'Salary vs Rating')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x='Dependancies',y='Salary',color='Blue')
plt.title('Salary vs Dependancies')
# Out:
# Text(0.5, 1.0, 'Salary vs Dependancies')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x='Billing',y='Salary',color='Red')
plt.title('Salary vs Billing')
# Out:
# Text(0.5, 1.0, 'Salary vs Billing')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x='Calls',y='Salary',color='yellow')
plt.title('Salary vs Calls')
# Out:
# Text(0.5, 1.0, 'Salary vs Calls')

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Volume',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('Volumevs Salary',fontsize=15)
sns.scatterplot(x=df['Volume'],y=df['Salary'],color='green')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Bonus',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('Bonus vs Salary',fontsize=15)
sns.scatterplot(x=df['Bonus'],y=df['Salary'],color='red')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Age',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('Age vs Salary',fontsize=15)
sns.scatterplot(x=df['Age'],y=df['Salary'],color='orange')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('openingbalance',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('openingbalance vs Salary',fontsize=15)
sns.scatterplot(x=df['openingbalance'],y=df['Salary'],color='green')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('closingbalance',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('closingbalance vs Salary',fontsize=15)
sns.scatterplot(x=df['closingbalance'],y=df['Salary'],color='green')
plt.show()

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Age')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Bonus')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Unit_Sales')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Volume')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Unit_Price')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='openingbalance')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='closingbalance')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Total_Sales')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Base_pay')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Business')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='low')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Months')

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column='Salary')

# %% [markdown]
# # Looking to the percentage of correlation

# %%
df3_numeric.corr(method='spearman')*100
# Out:
#                        Age      Salary    Base_pay       Bonus  Unit_Price  \
# Age             100.000000   20.228180   20.212073   20.228180   12.826637
# Salary           20.228180  100.000000   99.997589  100.000000   81.171311
# Base_pay         20.212073   99.997589  100.000000   99.997589   81.168113
# Bonus            20.228180  100.000000   99.997589  100.000000   81.171311
# Unit_Price       12.826637   81.171311   81.168113   81.171311  100.000000
# Volume           -3.934477  -39.048779  -39.042656  -39.048779  -32.422983
# openingbalance   -5.291931   45.346909   45.285139   45.346909   33.340773
# closingbalance   44.098882   34.649833   34.640860   34.649833   26.369923
# low              20.203950   99.985870   99.983405   99.985870   81.241207
# Unit_Sales       20.226808   99.999741   99.997324   99.999741   81.173482
# Total_Sales      20.217192   99.996492   99.994077   99.996492   81.170424
# ...

# %% [markdown]
# # Drop the non-required variables

# %%
dff=df.drop(columns=['Gender','Business','openingbalance',	'Calls','Type','Rating','Billing','Total_Sales','closingbalance','Volume','Bonus','Base_pay','Dependancies','Unit_Price','Unit_Sales','low'])
dff.head()
# Out:
#    Age   Salary  Months            Education
# 0   18  5089.00       0  High School or less
# 1   19  5698.12       0  High School or less
# 2   22  5896.65       0  High School or less
# 3   21  6125.12       0  High School or less
# 4   23  6245.00       1  High School or less

# %% [markdown]
# # Label encoding to convert categorical data to into numerical data

# %%
dff['Education']=dff['Education'].map({'High School or less':0,'Intermediate':1,'Graduation':2,'PG':3})
# assingning high school =0,Intermediate=1 and graduation=2

# %%
dff.head()
# Out:
#    Age   Salary  Months  Education
# 0   18  5089.00       0          0
# 1   19  5698.12       0          0
# 2   22  5896.65       0          0
# 3   21  6125.12       0          0
# 4   23  6245.00       1          0

# %% [markdown]
# # Handling Outliers

# %%
Q1=dff.quantile(0.25).round(3)
Q3=dff.quantile(0.75).round(3)
IQR=Q3-Q1
print(IQR)
# Out:
# Age             10.000
# Salary       33021.753
# Months          47.000
# Education        1.000
# dtype: float64

# %%
dfout = dff[~((dff<(Q1 - 1.5*IQR)) | (dff>(Q3 + 1.5*IQR))).any(axis=1)]
dfout.shape
# Out:
# (4833, 4)

# %% [markdown]
# # we can see there is no outliers in bonus now

# %%
sns.boxplot(x=dfout['Age'])
plt.show()

# %%
sns.boxplot(x=dfout['Salary'])
plt.show()

# %%
sns.boxplot(x=dfout['Months'])
plt.show()

# %%
x=dff.drop(['Salary'],axis=1)
x
# Out:
#       Age  Months  Education
# 0      18       0          0
# 1      19       0          0
# 2      22       0          0
# 3      21       0          0
# 4      23       1          0
# ...   ...     ...        ...
# 4995   72      72          3
# 4996   73      72          3
# 4997   74      72          3
# 4998   74      72          3
# 4999   88      72          3
#
# [5000 rows x 3 columns]

# %% [markdown]
# # Dependent Varaible

# %%
y=dff['Salary']
y
# Out:
# 0         5089.00
# 1         5698.12
# 2         5896.65
# 3         6125.12
# 4         6245.00
#           ...
# 4995    180696.80
# 4996    185685.90
# 4997    192636.80
# 4998    195970.70
# 4999    199970.74
# Name: Salary, Length: 5000, dtype: float64

# %% [markdown]
# # split x and y into training and testing sets

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
#       Age  Months  Education
# 2858   45      21          2
# 1559   47       1          3
# 1441   45       1          3
# 2179   55       7          3
# 1390   44       1          2
# ...   ...     ...        ...
# 4931   63      72          3
# 3264   40      31          3
# 1653   48       2          2
# 2607   62      15          2
# 2732   68      18          2
#
# [3500 rows x 3 columns]

# %%
x_test
# Out:
#       Age  Months  Education
# 398    49      12          3
# 3833   39      48          2
# 4836   59      72          3
# 4572   51      68          3
# 636    53      27          3
# ...   ...     ...        ...
# 4554   50      68          3
# 4807   58      72          3
# 1073   64      63          3
# 2906   48      22          3
# 1357   43       1          3
#
# [1500 rows x 3 columns]

# %%
y_train
# Out:
# 2858    104938.82440
# 1559     88835.89005
# 1441     86903.28139
# 2179     96844.15570
# 1390     86096.55833
#             ...
# 4931    151880.35890
# 3264    110244.51700
# 1653     90043.98773
# 2607    101985.79940
# 2732    103369.50500
# Name: Salary, Length: 3500, dtype: float64

# %%
y_test
# Out:
# 398      64631.43297
# 3833    118137.14110
# 4836    143137.34650
# 4572    133346.50250
# 636      73049.74210
#             ...
# 4554    132723.77580
# 4807    141312.27900
# 1073     81265.54772
# 2906    105472.97890
# 1357     85510.67637
# Name: Salary, Length: 1500, dtype: float64

# %% [markdown]
# # Data Normalization with sklearn

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
# fit scaler on trainindg data
x_train=sc.fit_transform(x_train)
# transform testing data
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.79810913, -0.45185117, -1.14142217],
#        [-0.56643739, -1.26180691,  0.79882921],
#        [-0.79810913, -1.26180691,  0.79882921],
#        ...,
#        [-0.45060152, -1.22130912, -1.14142217],
#        [ 1.17110062, -0.69483789, -1.14142217],
#        [ 1.86611582, -0.57334453, -1.14142217]])

# %%
x_test
# Out:
# array([[-0.33476566, -0.81633125,  0.79882921],
#        [-1.49312433,  0.64158909, -1.14142217],
#        [ 0.82359302,  1.61353598,  0.79882921],
#        ...,
#        [ 1.40277236,  1.24905589,  0.79882921],
#        [-0.45060152, -0.41135338,  0.79882921],
#        [-1.02978086, -1.26180691,  0.79882921]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Create and train the Linear Regression model
model_lr = LinearRegression()
model_lr.fit(x_train, y_train)

# Make predictions
y_pred_lr = model_lr.predict(x_test)

# Calculate performance metrics
mae_lr = mean_absolute_error(y_test, y_pred_lr)
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
mape_lr = np.mean(np.abs((y_test - y_pred_lr) / np.abs(y_test)))
accuracy_lr = 100 * (1 - mape_lr)

# Print the performance metrics for Linear Regression
print('Linear Regression Metrics:')
print('Mean Absolute Error (MAE):', mae_lr)
print('Mean Squared Error (MSE):', mse_lr)
print('Root Mean Squared Error (RMSE):', rmse_lr)
print('Mean Absolute Percentage Error (MAPE):', round(mape_lr * 100, 2))
print('Accuracy:', round(accuracy_lr, 2))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error (MAE): 15319.356348066767
# Mean Squared Error (MSE): 343537924.4925686
# Root Mean Squared Error (RMSE): 18534.776084230652
# Mean Absolute Percentage Error (MAPE): 21.73
# Accuracy: 78.27

# %%
from sklearn.tree import DecisionTreeRegressor

# Create and train the Decision Tree model
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Calculate performance metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
accuracy = 100 * (1 - mape)

# Print the performance metrics
print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# Mean Absolute Error (MAE): 406.37341874863085
# Mean Squared Error (MSE): 4732201.137479301
# Root Mean Squared Error (RMSE): 2175.362300279956
# Mean Absolute Percentage Error (MAPE): 0.65
# Accuracy: 99.35

# %%
from sklearn.ensemble import RandomForestRegressor

# Create and train the Decision Tree model
model_rf = RandomForestRegressor(n_estimators=100,random_state=42)
model_rf.fit(x_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(x_test)

# Calculate performance metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mape_rf = np.mean(np.abs((y_test - y_pred_rf) / np.abs(y_test)))
accuracy_rf = 100 * (1 - mape_rf)

# Print the performance metrics
print('Random Forest Metrics:')
print('Mean Absolute Error (MAE):', mae_rf)
print('Mean Squared Error (MSE):', mse_rf)
print('Root Mean Squared Error (RMSE):', rmse_rf)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# Random Forest Metrics:
# Mean Absolute Error (MAE): 471.3135654212404
# Mean Squared Error (MSE): 5406714.717223343
# Root Mean Squared Error (RMSE): 2325.234335980643
# Mean Absolute Percentage Error (MAPE): 0.65
# Accuracy: 99.35

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# Create and train the Decision Tree model
model_xgb = xgb.XGBRegressor()
model_xgb.fit(x_train, y_train)

# Make predictions
y_pred_xgb = model_xgb.predict(x_test)

# Calculate performance metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mape_xgb = np.mean(np.abs((y_test - y_pred_xgb) / np.abs(y_test)))
accuracy_xgb = 100 * (1 - mape_xgb)

# Print the performance metrics
print('XGBoost Metrics:')
print('Mean Absolute Error (MAE):', mae_xgb)
print('Mean Squared Error (MSE):', mse_xgb)
print('Root Mean Squared Error (RMSE):', rmse_xgb)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# XGBoost Metrics:
# Mean Absolute Error (MAE): 497.28014051747914
# Mean Squared Error (MSE): 5500086.227493529
# Root Mean Squared Error (RMSE): 2345.2262636030514
# Mean Absolute Percentage Error (MAPE): 0.65
# Accuracy: 99.35

# %%
# Cross Validation for our model
from sklearn.model_selection import ShuffleSplit, cross_val_score
model=LinearRegression()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print('nMean Cross-validation Accuracy:',np.mean(results))
# Out:
# [0.45734947 0.45027134 0.43717549 0.43547792 0.45755296 0.47702249
#  0.4761673  0.43388795 0.4535373  0.46811764]
# nMean Cross-validation Accuracy: 0.45465598651064676

# %%
# Cross Validation for our model
model=DecisionTreeRegressor(max_depth=3)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print('nMean Cross-validation Accuracy:',np.mean(results))
# Out:
# [0.57255302 0.55498111 0.60207561 0.56006275 0.53133059 0.49269968
#  0.6793919  0.52175112 0.5187091  0.49941874]
# nMean Cross-validation Accuracy: 0.5532973600683967

# %%
# Cross Validation for our model
model=RandomForestRegressor(random_state=3)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print('nMean Cross-validation Accuracy:',np.mean(results))
# Out:
# [0.99155078 0.9919948  0.98512047 0.98875472 0.98806222 0.99154851
#  0.98076799 0.9898275  0.98808469 0.98102703]
# nMean Cross-validation Accuracy: 0.9876738705766941

# %%
# Cross Validation for our model
model=xgb.XGBRegressor()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print('nMean Cross-validation Accuracy:',np.mean(results))
# Out:
# [0.99021934 0.99324562 0.99323021 0.98951112 0.98392757 0.98995116
#  0.9857321  0.98472108 0.99070544 0.98716509]
# nMean Cross-validation Accuracy: 0.988840872503928

# %% [markdown]
# Results

# %%
1) At fisrt we have read the dataset using pd.Dataframe().
2) Then we visualize the dataset by using head(),tail(),shape(),describe(),size(),info().
3) we have found the shape of data is 5000 row and 20 column.
4) using tail(),head(),info(),isnull().sum().we have found the presence of null values in the dataset.
5) After finding the null values we have removed them using the concept of KNN Imputer.
6) Dataset having Data Total_Sales consist of some blank rows, that are replaced by NAN followed by mean value.
7) For better understanding of data different categorical data are plotted against there  respective count.
8) For checking the gender ratio ,we have used Gender column from dataset.We have noticed after plotting that there
is negligible difference.
9) we have found that large number of employees get hired by the company using month column.
10) By using age column, we get to know that most of the employee are seniors with mean age observed as 51.
11) we have detected the presence of outliers in the dataset by data normalization.
12) By Using Heatmap,spearman correlation was obtained and it was found that thew correlation between Total_Sales 
and Salary(depedent variable) is 0.99.
13) The result of correlation tells that it is perfectly monotonically increasing relationship and salary 
linearly increases with Total_Sales.
14) Using Spearman table we can tell that the employees that sells more is getting more salary.Similarly all 
other features are observed using the table.
15) Nextly diffrent Catagorical data and dependent variable(Salary) was analyzed.
16) By plotting Gender vs Salary , we can tell that male and female are almost equal in number in the company.
17) Also using the same plot , we can tell that both the genders are drawing equal number of salary from company.
18) At next , we have observed that mean of both the person who has business or not is almost same.
19) By plot Salary Vs Education ,we get to know that more educated employees are receiving more salary . PG degree draws
approx 50000-2 Lakh, graduate are recieving from 25000-1Lakh,where as HIgh SChool or less and intermediate are recieving less than 25000.
20) We have obseved that high  number of Unit_Sales results in  higher salary.
# Out:
#   Cell In[103], line 1
#     1) At fisrt we have read the dataset using pd.Dataframe().
#      ^
# SyntaxError: unmatched ')'
